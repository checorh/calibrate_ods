# %%
from sumo_python.helpers.load_experiment_metadata import load_experiment_config
input_path = "/Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/"

config, sim_setup = load_experiment_config(config=input_path + 'config.json',
                        sim_setup=input_path + 'simulation_setups.json',)
import numpy as np
import pandas as pd

from sumo_python.helpers.generate_od_xml import generate_od_xml
from sumo_python.simulator.run_sumo_and_parse_output import run_sumo_and_parse_output
from sumo_python.simulator.ground_truth import run_ground_truth_and_parse
from sumo_python.helpers.nrmse_counts import compute_nrmse_counts

df_gt_data = run_ground_truth_and_parse(config, sim_setup)
# Out:
# od2trips --no-step-log  --spread.uniform --taz-files /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/quickstart.taz.xml --tazrelation-files /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/quickstart.gt_od.xml -o /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/gt_od_trips.trips.xml
# Success.
# sumo --output-prefix gt_ --ignore-route-errors=true --net-file=/Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/quickstart.net.xml --routes=/Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/gt_od_trips.trips.xml -b 54000 -e 57600 --additional-files /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/quickstart.additional.xml --duration-log.statistics --xml-validation never --vehroutes /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/gt_routes.vehroutes.xml
# Loading net-file from '/Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/quickstart.net.xml' ... done (7ms).
# Loading additional-files from '/Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/quickstart.additional.xml' ... done (2ms).
# Loading done.
# Simulation version 1.16.0 started with time: 54000.00.
# Step #57600.00 (9ms ~= 111.11*RT, ~72888.89UPS, vehicles TOT 2800 ACT 656 BUF 0)
# Simulation ended at time: 57600.00
# Reason: The final simulation step has been reached.
# Performance:
#  Duration: 15.03s
#  Real time factor: 239.569
#  UPS: 107618.420177
# Vehicles:
#  Inserted: 2800
#  Running: 656
#  Waiting: 0
# Statistics (avg of 2144):
#  RouteLength: 4392.77
#  Speed: 11.24
#  Duration: 471.78
#  WaitingTime: 81.10
#  TimeLoss: 153.11
#  DepartDelay: 0.10
#
# DijkstraRouter answered 2800 queries and explored 10.01 edges on average.
# DijkstraRouter spent 0.01s answering queries (0.00ms on average).

# %%
import os
import math
from dataclasses import dataclass

import torch
from botorch.acquisition import qExpectedImprovement
from botorch.fit import fit_gpytorch_mll
from botorch.generation import MaxPosteriorSampling
from botorch.models import SingleTaskGP
from botorch.optim import optimize_acqf
from botorch.test_functions import Ackley
from botorch.utils.transforms import unnormalize
from botorch.utils.transforms import normalize
from torch.quasirandom import SobolEngine

import gpytorch
from gpytorch.constraints import Interval
from gpytorch.kernels import MaternKernel, ScaleKernel
from gpytorch.likelihoods import GaussianLikelihood
from gpytorch.mlls import ExactMarginalLogLikelihood
from gpytorch.priors import HorseshoePrior

from botorch.models.transforms import Standardize


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype = torch.double
SMOKE_TEST = os.environ.get("SMOKE_TEST")

# %% [markdown]
# ## Maintain the TuRBO state
#
# https://proceedings.neurips.cc/paper/2019/file/6c990b7aca7bc7058f5e98ea909e924b-Paper.pdf
#
# TuRBO needs to maintain a state, which includes the length of the trust region, success and failure counters, success and failure tolerance, etc.
#
# In this tutorial we store the state in a dataclass and update the state of TuRBO after each batch evaluation.
#
# Note: These settings assume that the domain has been scaled to [0,1]𝑑
#  and that the same batch size is used for each iteration.

# %%
@dataclass
class TurboState:
    dim: int
    batch_size: int
    length: float = 0.8
    length_min: float = 0.5**7
    length_max: float = 1.6
    failure_counter: int = 0
    failure_tolerance: int = float("nan")  # Note: Post-initialized
    success_counter: int = 0
    success_tolerance: int = 3  # Note: The original paper uses 3
    best_value: float = -float("inf")
    restart_triggered: bool = False

    def __post_init__(self):
        self.failure_tolerance = math.ceil(
            max([4.0 / self.batch_size, float(self.dim) / self.batch_size])
        )


def update_state(state, Y_next):
    if max(Y_next) > state.best_value + 1e-3 * math.fabs(state.best_value):
        state.success_counter += 1
        state.failure_counter = 0
    else:
        state.success_counter = 0
        state.failure_counter += 1

    if state.success_counter == state.success_tolerance:  # Expand trust region
        state.length = min(2.0 * state.length, state.length_max)
        state.success_counter = 0
    elif state.failure_counter == state.failure_tolerance:  # Shrink trust region
        state.length /= 2.0
        state.failure_counter = 0

    state.best_value = max(state.best_value, max(Y_next).item())
    if state.length < state.length_min:
        state.restart_triggered = True
    return state

# %% [markdown]
# # Generate new batch
#
# Given the current state and a probabilistic (GP) model built from observations X and Y, we generate a new batch of points.
#
# This method works on the domain [0,1]𝑑
# , so make sure to not pass in observations from the true domain. unnormalize is called before the true function is evaluated which will first map the points back to the original domain.
#
# We support either TS and qEI which can be specified via the acqf argument.

# %%
def generate_batch(
    state,
    model,  # GP model
    X,  # Evaluated points on the domain [0, 1]^d
    Y,  # Function values
    batch_size,
    n_candidates=None,  # Number of candidates for Thompson sampling
    num_restarts=10,
    raw_samples=512,
    acqf="ts",  # "ei" or "ts"
):
    assert acqf in ("ts", "ei")
    assert X.min() >= 0.0 and X.max() <= 1.0 and torch.all(torch.isfinite(Y))
    if n_candidates is None:
        n_candidates = min(5000, max(2000, 200 * X.shape[-1]))

    # Scale the TR to be proportional to the lengthscales
    x_center = X[Y.argmax(), :].clone()
    weights = model.covar_module.base_kernel.lengthscale.squeeze().detach()
    weights = weights / weights.mean()
    weights = weights / torch.prod(weights.pow(1.0 / len(weights)))
    tr_lb = torch.clamp(x_center - weights * state.length / 2.0, 0.0, 1.0)
    tr_ub = torch.clamp(x_center + weights * state.length / 2.0, 0.0, 1.0)

    if acqf == "ts":
        dim = X.shape[-1]
        sobol = SobolEngine(dim, scramble=True)
        pert = sobol.draw(n_candidates).to(dtype=dtype, device=device)
        pert = tr_lb + (tr_ub - tr_lb) * pert

        # Create a perturbation mask
        prob_perturb = min(20.0 / dim, 1.0)
        mask = torch.rand(n_candidates, dim, dtype=dtype, device=device) <= prob_perturb
        ind = torch.where(mask.sum(dim=1) == 0)[0]
        mask[ind, torch.randint(0, dim - 1, size=(len(ind),), device=device)] = 1

        # Create candidate points from the perturbations and the mask
        X_cand = x_center.expand(n_candidates, dim).clone()
        X_cand[mask] = pert[mask]

        # Sample on the candidate points
        thompson_sampling = MaxPosteriorSampling(model=model, replacement=False)
        with torch.no_grad():  # We don't need gradients when using TS
            X_next = thompson_sampling(X_cand, num_samples=batch_size)

    elif acqf == "ei":
        ei = qExpectedImprovement(model, train_Y.max(), maximize=True)
        X_next, acq_value = optimize_acqf(
            ei,
            bounds=torch.stack([tr_lb, tr_ub]),
            q=batch_size,
            num_restarts=num_restarts,
            raw_samples=raw_samples,
        )

    return X_next

# %% [markdown]
# # Optimization loop
#
# This simple loop runs one instance of TuRBO-1 with Thompson sampling until convergence.
#
# TuRBO-1 is a local optimizer that can be used for a fixed evaluation budget in a multi-start fashion. Once TuRBO converges, state["restart_triggered"] will be set to true and the run should be aborted. If you want to run more evaluations with TuRBO, you simply generate a new set of initial points and then keep generating batches until convergence or when the evaluation budget has been exceeded. It's important to note that evaluations from previous instances are discarded when TuRBO restarts.
#
# NOTE: We use a SingleTaskGP with a noise constraint to keep the noise from getting too large as the problem is noise-free.

# %%
import numpy as np
import pandas as pd
def objective(x: np.array) -> pd.DataFrame:
    """Compute objective variable. This is the NRMSE loss between ground-truth output
    and the output of the simulation output evaluated at x.

    Args:
        x (np.array): Numpy array of counts to generate TAZ file from.

    Returns:
        pd.Dataframe: Data frame of sampling locations and loss esimate.
    """
    prefix_run = 'iter'    
    generate_od_xml(x, config, sim_setup, prefix_run)
    df_simulated = run_sumo_and_parse_output(config, sim_setup, prefix_run)
    loss_estimate = compute_nrmse_counts(df_gt_data, df_simulated)
    df_output = pd.DataFrame(x.reshape(-1, len(x)),columns = ['x1','x2','x3','x4'])
    df_output['loss_estimate'] = loss_estimate
    
    return df_output

# %%
import os
import torch

device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")
dtype = torch.double

### Declare search space
# dimensionality of input space
bounds = torch.tensor([[400,400,400,400],[1000,1000,1000,1000]], device=device, dtype=dtype) 
bounds
# Out:
# tensor([[ 400.,  400.,  400.,  400.],
#         [1000., 1000., 1000., 1000.]], dtype=torch.float64)

# %% [markdown]
# ### Initial sampling locations

# %%
df_0 = pd.read_csv('./data/initial_sampling_locations.csv')

# %% [markdown]
# ### Run loop

# %%
batch_size = 1
dim=4
state = TurboState(dim, batch_size)

SMOKE_TEST  = False
NUM_RESTARTS = 10 if not SMOKE_TEST else 2
RAW_SAMPLES = 512 if not SMOKE_TEST else 4
N_CANDIDATES = min(5000, max(2000, 200 * dim)) if not SMOKE_TEST else 4
max_cholesky_size = float("inf")  # Always use Cholesky

torch.manual_seed(0)

### Run loop
NITER = 100
output = [df_0]
best_value = []


for i in range(NITER):
    
    print(f"####### {i+1} ########")
    
    df_ = df_0 if i == 0 else df_i
    
    n_obs = df_.shape[0]
    print(f"##### n={n_obs} #####")
    
    # Training data
    train_X = torch.from_numpy(df_[["x1","x2","x3","x4"]].values)    
    train_X_norm = normalize(train_X,bounds)
    
    train_Y = -1.0 * torch.from_numpy(df_[["loss_estimate"]].values) 
    
    # best value so far
    best_y = train_Y.max()
    best_value.append(best_y)
    print(f"##### best_value={best_y} #####")

    # Update state
    state = update_state(state=state, Y_next=train_Y)

    # Fit a GP model
    #train_Y = (Y_turbo - Y_turbo.mean()) / Y_turbo.std()
    likelihood = GaussianLikelihood(noise_constraint=Interval(1e-8, 1e-3))
    covar_module = ScaleKernel(  # Use the same lengthscale prior as in the TuRBO paper
        MaternKernel(
            nu=2.5, ard_num_dims=dim, lengthscale_constraint=Interval(0.005, 4.0)
        )
    )
    model = SingleTaskGP(
        train_X_norm, train_Y, 
        covar_module=covar_module, likelihood=likelihood, 
        outcome_transform=Standardize(m=1)
    )
    mll = ExactMarginalLogLikelihood(model.likelihood, model)

    # Do the fitting and acquisition function optimization inside the Cholesky context
    with gpytorch.settings.max_cholesky_size(max_cholesky_size):
        # Fit the model
        fit_gpytorch_mll(mll)

        # Create a batch
        new_x_turbo = generate_batch(
            state=state,
            model=model,
            X=train_X_norm,
            Y=train_Y,
            batch_size=batch_size,
            n_candidates=N_CANDIDATES,
            num_restarts=NUM_RESTARTS,
            raw_samples=RAW_SAMPLES,
            acqf="ei", # "ts"
        )

    new_x = unnormalize(new_x_turbo,bounds)

    # Query SUMO on new sampling location
    df_simulation = objective(new_x.cpu().detach().numpy().reshape(-1))
    df_simulation['iter'] = i+1
    
    # Update history of training data
    output.append(df_simulation)
    
    df_i = pd.concat(output)

    # Print current status
    print(
        f"Best value: {state.best_value:.2e}, TR length: {state.length:.2e}"
    )
# Out:
# ####### 1 ########
# ##### n=20 #####
# ##### best_value=-0.027004666207663 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~111875.00UPS, vehicles TOT 3176 ACT 895 BUF 25)
# Best value: -2.70e-02, TR length: 8.00e-01
# ####### 2 ########
# ##### n=21 #####
# ##### best_value=-0.027004666207663 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~93750.00UPS, vehicles TOT 3017 ACT 750 BUF 0)
# Best value: -2.70e-02, TR length: 8.00e-01
# ####### 3 ########
# ##### n=22 #####
# ##### best_value=-0.027004666207663 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (7ms ~= 142.86*RT, ~116142.86UPS, vehicles TOT 3036 ACT 813 BUF 0)
# Best value: -2.70e-02, TR length: 8.00e-01
# ####### 4 ########
# ##### n=23 #####
# ##### best_value=-0.027004666207663 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (10ms ~= 100.00*RT, ~87200.00UPS, vehicles TOT 3028 ACT 872 BUF 184)
# Best value: -2.70e-02, TR length: 4.00e-01
# ####### 5 ########
# ##### n=24 #####
# ##### best_value=-0.023271803769880032 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (6ms ~= 166.67*RT, ~114333.33UPS, vehicles TOT 2758 ACT 686 BUF 0)
# Best value: -2.33e-02, TR length: 4.00e-01
# ####### 6 ########
# ##### n=25 #####
# ##### best_value=-0.023271803769880032 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (5ms ~= 200.00*RT, ~162400.00UPS, vehicles TOT 2946 ACT 812 BUF 194)
# Best value: -2.33e-02, TR length: 4.00e-01
# ####### 7 ########
# ##### n=26 #####
# ##### best_value=-0.023271803769880032 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (7ms ~= 142.86*RT, ~128142.86UPS, vehicles TOT 3145 ACT 897 BUF 0)
# Best value: -2.33e-02, TR length: 4.00e-01
# ####### 8 ########
# ##### n=27 #####
# ##### best_value=-0.023271803769880032 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (7ms ~= 142.86*RT, ~122285.71UPS, vehicles TOT 2969 ACT 856 BUF 181)
# Best value: -2.33e-02, TR length: 4.00e-01
# ####### 9 ########
# ##### n=28 #####
# ##### best_value=-0.023271803769880032 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (6ms ~= 166.67*RT, ~133666.67UPS, vehicles TOT 2999 ACT 802 BUF 298)
# Best value: -2.33e-02, TR length: 2.00e-01
# ####### 10 ########
# ##### n=29 #####
# ##### best_value=-0.023271803769880032 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (6ms ~= 166.67*RT, ~149666.67UPS, vehicles TOT 3045 ACT 898 BUF 99)
# Best value: -2.33e-02, TR length: 2.00e-01
# ####### 11 ########
# ##### n=30 #####
# ##### best_value=-0.02120366490450273 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (6ms ~= 166.67*RT, ~141666.67UPS, vehicles TOT 2960 ACT 850 BUF 319)
# Best value: -2.12e-02, TR length: 2.00e-01
# ####### 12 ########
# ##### n=31 #####
# ##### best_value=-0.02120366490450273 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (6ms ~= 166.67*RT, ~143666.67UPS, vehicles TOT 2999 ACT 862 BUF 200)
# Best value: -2.12e-02, TR length: 2.00e-01
# ####### 13 ########
# ##### n=32 #####
# ##### best_value=-0.02120366490450273 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (14ms ~= 71.43*RT, ~59642.86UPS, vehicles TOT 3001 ACT 835 BUF 0)
# Best value: -2.12e-02, TR length: 2.00e-01
# ####### 14 ########
# ##### n=33 #####
# ##### best_value=-0.006422404915409151 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (6ms ~= 166.67*RT, ~120833.33UPS, vehicles TOT 2874 ACT 725 BUF 0)
# Best value: -6.42e-03, TR length: 2.00e-01
# ####### 15 ########
# ##### n=34 #####
# ##### best_value=-0.006422404915409151 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (6ms ~= 166.67*RT, ~143000.00UPS, vehicles TOT 2987 ACT 858 BUF 16)
# Best value: -6.42e-03, TR length: 2.00e-01
# ####### 16 ########
# ##### n=35 #####
# ##### best_value=-0.006422404915409151 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~104375.00UPS, vehicles TOT 2974 ACT 835 BUF 0)
# Best value: -6.42e-03, TR length: 2.00e-01
# ####### 17 ########
# ##### n=36 #####
# ##### best_value=-0.006422404915409151 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~87666.67UPS, vehicles TOT 2949 ACT 789 BUF 36)
# Best value: -6.42e-03, TR length: 2.00e-01
# ####### 18 ########
# ##### n=37 #####
# ##### best_value=-0.00287218679397673 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~102250.00UPS, vehicles TOT 2945 ACT 818 BUF 7)
# Best value: -2.87e-03, TR length: 2.00e-01
# ####### 19 ########
# ##### n=38 #####
# ##### best_value=-0.00287218679397673 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~97000.00UPS, vehicles TOT 2962 ACT 776 BUF 35)
# Best value: -2.87e-03, TR length: 2.00e-01
# ####### 20 ########
# ##### n=39 #####
# ##### best_value=-0.00287218679397673 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (5ms ~= 200.00*RT, ~162800.00UPS, vehicles TOT 2960 ACT 814 BUF 22)
# Best value: -2.87e-03, TR length: 2.00e-01
# ####### 21 ########
# ##### n=40 #####
# ##### best_value=-0.00287218679397673 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (5ms ~= 200.00*RT, ~166000.00UPS, vehicles TOT 2967 ACT 830 BUF 0)
# Best value: -2.87e-03, TR length: 2.00e-01
# ####### 22 ########
# ##### n=41 #####
# ##### best_value=-0.00287218679397673 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~89222.22UPS, vehicles TOT 2973 ACT 803 BUF 48)
# Best value: -2.87e-03, TR length: 1.00e-01
# ####### 23 ########
# ##### n=42 #####
# ##### best_value=-0.00287218679397673 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (6ms ~= 166.67*RT, ~143166.67UPS, vehicles TOT 3021 ACT 859 BUF 0)
# Best value: -2.87e-03, TR length: 1.00e-01
# ####### 24 ########
# ##### n=43 #####
# ##### best_value=-0.00287218679397673 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~85111.11UPS, vehicles TOT 2918 ACT 766 BUF 24)
# Best value: -2.87e-03, TR length: 1.00e-01
# ####### 25 ########
# ##### n=44 #####
# ##### best_value=-0.00287218679397673 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (6ms ~= 166.67*RT, ~133166.67UPS, vehicles TOT 2965 ACT 799 BUF 0)
# Best value: -2.87e-03, TR length: 1.00e-01
# ####### 26 ########
# ##### n=45 #####
# ##### best_value=-0.00287218679397673 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~100000.00UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.87e-03, TR length: 5.00e-02
# ####### 27 ########
# ##### n=46 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~94750.00UPS, vehicles TOT 2955 ACT 758 BUF 0)
# Best value: -2.03e-03, TR length: 5.00e-02
# ####### 28 ########
# ##### n=47 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (7ms ~= 142.86*RT, ~114857.14UPS, vehicles TOT 2934 ACT 804 BUF 42)
# Best value: -2.03e-03, TR length: 5.00e-02
# ####### 29 ########
# ##### n=48 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (7ms ~= 142.86*RT, ~116714.29UPS, vehicles TOT 2968 ACT 817 BUF 0)
# Best value: -2.03e-03, TR length: 5.00e-02
# ####### 30 ########
# ##### n=49 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~102125.00UPS, vehicles TOT 2968 ACT 817 BUF 0)
# Best value: -2.03e-03, TR length: 5.00e-02
# ####### 31 ########
# ##### n=50 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (10ms ~= 100.00*RT, ~77500.00UPS, vehicles TOT 2953 ACT 775 BUF 14)
# Best value: -2.03e-03, TR length: 2.50e-02
# ####### 32 ########
# ##### n=51 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~91888.89UPS, vehicles TOT 2981 ACT 827 BUF 0)
# Best value: -2.03e-03, TR length: 2.50e-02
# ####### 33 ########
# ##### n=52 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (10ms ~= 100.00*RT, ~82400.00UPS, vehicles TOT 2970 ACT 824 BUF 0)
# Best value: -2.03e-03, TR length: 2.50e-02
# ####### 34 ########
# ##### n=53 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (10ms ~= 100.00*RT, ~75500.00UPS, vehicles TOT 2955 ACT 755 BUF 9)
# Best value: -2.03e-03, TR length: 2.50e-02
# ####### 35 ########
# ##### n=54 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (11ms ~= 90.91*RT, ~71909.09UPS, vehicles TOT 2959 ACT 791 BUF 3)
# Best value: -2.03e-03, TR length: 1.25e-02
# ####### 36 ########
# ##### n=55 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~101125.00UPS, vehicles TOT 2974 ACT 809 BUF 0)
# Best value: -2.03e-03, TR length: 1.25e-02
# ####### 37 ########
# ##### n=56 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~86888.89UPS, vehicles TOT 2941 ACT 782 BUF 32)
# Best value: -2.03e-03, TR length: 1.25e-02
# ####### 38 ########
# ##### n=57 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~98875.00UPS, vehicles TOT 2958 ACT 791 BUF 11)
# Best value: -2.03e-03, TR length: 1.25e-02
# ####### 39 ########
# ##### n=58 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~95500.00UPS, vehicles TOT 2934 ACT 764 BUF 36)
# Best value: -2.03e-03, TR length: 6.25e-03
# ####### 40 ########
# ##### n=59 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~85111.11UPS, vehicles TOT 2951 ACT 766 BUF 21)
# Best value: -2.03e-03, TR length: 6.25e-03
# ####### 41 ########
# ##### n=60 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~96750.00UPS, vehicles TOT 2968 ACT 774 BUF 0)
# Best value: -2.03e-03, TR length: 6.25e-03
# ####### 42 ########
# ##### n=61 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (10ms ~= 100.00*RT, ~82300.00UPS, vehicles TOT 2965 ACT 823 BUF 0)
# Best value: -2.03e-03, TR length: 6.25e-03
# ####### 43 ########
# ##### n=62 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~100000.00UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 3.13e-03
# ####### 44 ########
# ##### n=63 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~86111.11UPS, vehicles TOT 2970 ACT 775 BUF 0)
# Best value: -2.03e-03, TR length: 3.13e-03
# ####### 45 ########
# ##### n=64 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~100750.00UPS, vehicles TOT 2968 ACT 806 BUF 1)
# Best value: -2.03e-03, TR length: 3.13e-03
# ####### 46 ########
# ##### n=65 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~97000.00UPS, vehicles TOT 2969 ACT 776 BUF 0)
# Best value: -2.03e-03, TR length: 3.13e-03
# ####### 47 ########
# ##### n=66 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (7ms ~= 142.86*RT, ~107714.29UPS, vehicles TOT 2927 ACT 754 BUF 43)
# Best value: -2.03e-03, TR length: 1.56e-03
# ####### 48 ########
# ##### n=67 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (14ms ~= 71.43*RT, ~55500.00UPS, vehicles TOT 2969 ACT 777 BUF 0)
# Best value: -2.03e-03, TR length: 1.56e-03
# ####### 49 ########
# ##### n=68 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~91555.56UPS, vehicles TOT 2969 ACT 824 BUF 0)
# Best value: -2.03e-03, TR length: 1.56e-03
# ####### 50 ########
# ##### n=69 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~97125.00UPS, vehicles TOT 2969 ACT 777 BUF 0)
# Best value: -2.03e-03, TR length: 1.56e-03
# ####### 51 ########
# ##### n=70 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~86333.33UPS, vehicles TOT 2969 ACT 777 BUF 0)
# Best value: -2.03e-03, TR length: 7.81e-04
# ####### 52 ########
# ##### n=71 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (10ms ~= 100.00*RT, ~78700.00UPS, vehicles TOT 2947 ACT 787 BUF 24)
# Best value: -2.03e-03, TR length: 7.81e-04
# ####### 53 ########
# ##### n=72 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~97125.00UPS, vehicles TOT 2969 ACT 777 BUF 0)
# Best value: -2.03e-03, TR length: 7.81e-04
# ####### 54 ########
# ##### n=73 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (10ms ~= 100.00*RT, ~77700.00UPS, vehicles TOT 2969 ACT 777 BUF 0)
# Best value: -2.03e-03, TR length: 7.81e-04
# ####### 55 ########
# ##### n=74 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 3.91e-04
# ####### 56 ########
# ##### n=75 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~97000.00UPS, vehicles TOT 2969 ACT 776 BUF 0)
# Best value: -2.03e-03, TR length: 3.91e-04
# ####### 57 ########
# ##### n=76 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~86222.22UPS, vehicles TOT 2969 ACT 776 BUF 0)
# Best value: -2.03e-03, TR length: 3.91e-04
# ####### 58 ########
# ##### n=77 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (13ms ~= 76.92*RT, ~59769.23UPS, vehicles TOT 2969 ACT 777 BUF 0)
# Best value: -2.03e-03, TR length: 3.91e-04
# ####### 59 ########
# ##### n=78 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 1.95e-04
# ####### 60 ########
# ##### n=79 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (10ms ~= 100.00*RT, ~80000.00UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 1.95e-04
# ####### 61 ########
# ##### n=80 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~86333.33UPS, vehicles TOT 2969 ACT 777 BUF 0)
# Best value: -2.03e-03, TR length: 1.95e-04
# ####### 62 ########
# ##### n=81 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~100000.00UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 1.95e-04
# ####### 63 ########
# ##### n=82 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (14ms ~= 71.43*RT, ~57142.86UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 9.77e-05
# ####### 64 ########
# ##### n=83 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~100000.00UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 9.77e-05
# ####### 65 ########
# ##### n=84 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~100000.00UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 9.77e-05
# ####### 66 ########
# ##### n=85 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~86333.33UPS, vehicles TOT 2969 ACT 777 BUF 0)
# Best value: -2.03e-03, TR length: 9.77e-05
# ####### 67 ########
# ##### n=86 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 4.88e-05
# ####### 68 ########
# ##### n=87 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (10ms ~= 100.00*RT, ~80000.00UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 4.88e-05
# ####### 69 ########
# ##### n=88 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 4.88e-05
# ####### 70 ########
# ##### n=89 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 4.88e-05
# ####### 71 ########
# ##### n=90 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 2.44e-05
# ####### 72 ########
# ##### n=91 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~100000.00UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 2.44e-05
# ####### 73 ########
# ##### n=92 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~100000.00UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 2.44e-05
# ####### 74 ########
# ##### n=93 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 2.44e-05
# ####### 75 ########
# ##### n=94 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 1.22e-05
# ####### 76 ########
# ##### n=95 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (7ms ~= 142.86*RT, ~114285.71UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 1.22e-05
# ####### 77 ########
# ##### n=96 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 1.22e-05
# ####### 78 ########
# ##### n=97 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~100000.00UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 1.22e-05
# ####### 79 ########
# ##### n=98 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 6.10e-06
# ####### 80 ########
# ##### n=99 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (11ms ~= 90.91*RT, ~72727.27UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 6.10e-06
# ####### 81 ########
# ##### n=100 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 6.10e-06
# ####### 82 ########
# ##### n=101 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 6.10e-06
# ####### 83 ########
# ##### n=102 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~100000.00UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 3.05e-06
# ####### 84 ########
# ##### n=103 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (11ms ~= 90.91*RT, ~72727.27UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 3.05e-06
# ####### 85 ########
# ##### n=104 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~100000.00UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 3.05e-06
# ####### 86 ########
# ##### n=105 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (10ms ~= 100.00*RT, ~80000.00UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 3.05e-06
# ####### 87 ########
# ##### n=106 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (10ms ~= 100.00*RT, ~80000.00UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 1.53e-06
# ####### 88 ########
# ##### n=107 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (10ms ~= 100.00*RT, ~80000.00UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 1.53e-06
# ####### 89 ########
# ##### n=108 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (10ms ~= 100.00*RT, ~80000.00UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 1.53e-06
# ####### 90 ########
# ##### n=109 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 1.53e-06
# ####### 91 ########
# ##### n=110 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 7.63e-07
# ####### 92 ########
# ##### n=111 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 7.63e-07
# ####### 93 ########
# ##### n=112 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 7.63e-07
# ####### 94 ########
# ##### n=113 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 7.63e-07
# ####### 95 ########
# ##### n=114 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~100000.00UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 3.81e-07
# ####### 96 ########
# ##### n=115 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 3.81e-07
# ####### 97 ########
# ##### n=116 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 3.81e-07
# ####### 98 ########
# ##### n=117 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 3.81e-07
# ####### 99 ########
# ##### n=118 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (8ms ~= 125.00*RT, ~100000.00UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 1.91e-07
# ####### 100 ########
# ##### n=119 #####
# ##### best_value=-0.0020309427588553947 #####
# printing /Users/rodrse/Documents/DemandCalibration/notebooks/od_calibration_sumo_files/quickstart/data/iter_quickstart.current_od.xml
# ### Runing: iter
# Success.
# Step #57600.00 (9ms ~= 111.11*RT, ~88888.89UPS, vehicles TOT 2959 ACT 800 BUF 9)
# Best value: -2.03e-03, TR length: 1.91e-07

# %%
df_plot = df_i.query('iter>0')
import numpy as np
import matplotlib.pyplot as plt

x = df_plot['iter']
y = df_plot['loss_estimate']

plt.plot(x, best_value)
#plt.legend(title='Parameter where:')
plt.show()
df_i.query('loss_estimate<0.010')
# Out:
#             x1          x2          x3          x4  loss_estimate  iter
# 0   734.995399  640.217550  866.129964  761.451422       0.006422    13
# 0   736.736187  645.180225  864.715903  740.993884       0.002872    17
# 0   753.019248  629.284839  846.976718  754.988371       0.009970    20
# 0   757.164276  638.737549  875.142706  751.502189       0.003211    22
# 0   695.606617  639.316537  892.843405  716.568514       0.009014    24
# ..         ...         ...         ...         ...            ...   ...
# 0   714.869388  637.904703  877.984464  740.905626       0.002031    96
# 0   714.869531  637.904729  877.984468  740.905584       0.002031    97
# 0   714.869482  637.904662  877.984441  740.905495       0.002031    98
# 0   714.869386  637.904786  877.984524  740.905549       0.002031    99
# 0   714.869399  637.904725  877.984588  740.905559       0.002031   100
#
# [63 rows x 6 columns]

# %%
df_i.to_csv("./data/turbo_ei.csv",index = None)
